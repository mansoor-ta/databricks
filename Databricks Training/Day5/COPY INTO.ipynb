-- %%
create table if not exists dev.mansoor.marks_info

-- %%
COPY INTO dev.mansoor.marks_info
FROM '/Volumes/dev/mansoor/marks_data/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('mergeSchema' = 'true','header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');

-- %%
select * from dev.mansoor.marks_info

-- %%
select * from dev.mansoor.month_copy
