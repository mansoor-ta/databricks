-- %%
select * from dev.mansoor.emp

-- %%
desc history dev.mansoor.emp

-- %%
desc extended dev.mansoor.emp
desc detail dev.mansoor.emp

-- %%
insert into dev.mansoor.emp values (10,'Shine', 'Delhi');
insert into dev.mansoor.emp values (10,'Shine', 'Delhi');
insert into dev.mansoor.emp values (10,'Shine', 'Delhi');
insert into dev.mansoor.emp values (10,'Shine', 'Delhi');
insert into dev.mansoor.emp values (10,'Shine', 'Delhi');

-- %%
 optimize dev.mansoor.emp
 zorder by (id)

-- %%
desc extended dev.mansoor.emp
desc history dev.mansoor.emp
desc detail dev.mansoor.emp

-- %%
vacuum dev.mansoor.emp

-- %%
ALTER TABLE dev.mansoor.emp SET TBLPROPERTIES ('delta.deletedFileRetentionDuration' = 'interval 0 hours')

-- %%
desc history dev.mansoor.emp
desc detail dev.mansoor.emp
