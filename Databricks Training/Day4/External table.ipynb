-- %%
create table dev.mansoor.vendor (id int, name string) location 's3://jpmctraining/allianz/mansoor'

-- %%
desc extended dev.mansoor.vendor

-- %%
insert into dev.mansoor.vendor values (1,'jio')

-- %%
select * from dev.mansoor.vendor

-- %%
select * from delta.`s3://jpmctraining/allianz/mansoor`

-- %%
undrop table dev.mansoor.vendor

-- %%
select * from dev.mansoor.vendor

-- %%
CREATE OR REPLACE TABLE dev.mansoor.emp_clone_deep
DEEP CLONE dev.mansoor.emp;

-- %%
CREATE OR REPLACE TABLE dev.mansoor.emp_clone_shallow
SHALLOW CLONE dev.mansoor.emp;

-- %%
select * from dev.mansoor.emp_clone_shallow;
delete from dev.mansoor.emp where id=10;
insert into dev.mansoor.emp_clone_shallow values (10,'abc','xyz')
