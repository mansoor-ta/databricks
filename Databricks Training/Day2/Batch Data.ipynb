# %%
# %sql
create table dev.mansoor.financial_data as 
select * from read_files("/Volumes/dev/naval/raw/financial_dataset.csv")

# %%
# %sql
select * from dev.mansoor.financial_data

# %%
# %sql
select * from read_files("/Volumes/dev/naval/raw/drivers.json")

# %%
# %sql
create table dev.mansoor.f1_driver_data as 
select * from read_files("/Volumes/dev/naval/raw/drivers.json")

# %%
# %sql
select * from dev.mansoor.f1_driver_data
