# %%
# %sql
create schema dev.mansoor

# %%
# %sql
create table dev.mansoor.employee (id int primary key, name string)

# %%
# %sql
insert into dev.mansoor.employee (id, name) values
  (1, 'Mansoor'),
  (2, 'Ali'),
  (3, 'Sara')

# %%
# %sql
select * from dev.mansoor.employee
