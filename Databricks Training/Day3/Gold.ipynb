-- %%
create or replace view dev.mansoor_gold.top_customers as 
select customer_id, sum(total_amount) as total from dev.mansoor_silver.sales_cleaned group by customer_id order by total desc limit 3

-- %%
select * from dev.mansoor_gold.top_customers
