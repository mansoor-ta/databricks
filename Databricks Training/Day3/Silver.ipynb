-- %%
%python
df=spark.table("dev.mansoor_bronze.sales")

-- %%
%python
df.display()

-- %%
%python
df1=df.dropDuplicates().dropna().drop("ingestion_date",'path')

df1.display()

-- %%
%python
df1.write.mode("overwrite").saveAsTable("dev.mansoor_silver.sales_cleaned")

-- %%
select * from dev.mansoor_silver.sales_cleaned
