-- %%
%sql
insert into dev.naval.emp values (100,'Mans','KL10')

-- %%
%sql
describe history dev.naval.emp

-- %%
%sql
create table if not exists dev.mansoor.emp (id int, name string, city string)

-- %%
insert into dev.mansoor.emp values (100,'Mansoor','TVM')
, (200,'Naval','MUM')
, (300,'Ravi','BLR')
, (400,'Raj','COC')
, (500,'Rana','DLH')

-- %%
describe history dev.mansoor.emp;
select * from dev.mansoor.emp VERSION AS OF 1

-- %%
%python
data=[(1,'Virat'),(2,'Rohit')]
schema="id int, name string"
df=spark.createDataFrame(data,schema)
df.createOrReplaceTempView("source")
